# %%
import pandas as pd
import matplotlib.pyplot as plt
file1=pd.read_csv("census data - Sheet1.csv")
print(file1)
# Out:
#     Language    1900    1911    1921    1931    1941    1951    1961    1971
# 0      Hindi  26.60%  28.90%  31.80%  32.10%  26.60%  44.30%  44.10%  43.10%  \
# 1    Bengali  10.80%  10.70%  11.00%  11.60%   8.00%   9.10%   9.20%   9.40%
# 2    Marathi   7.10%   7.60%   7.90%   7.80%   6.80%   7.00%   7.10%   7.30%
# 3     Telugu   5.90%   6.20%   6.40%   6.60%   6.70%   7.20%   7.30%   7.50%
# 4      Tamil   5.30%   5.50%   5.70%   5.90%   6.30%   6.80%   7.00%   7.30%
# 5   Gujarati   4.30%   4.60%   4.80%   4.90%   5.00%   5.30%   5.50%   5.70%
# 6       Urdu   2.50%   2.90%   3.20%   3.40%   4.20%   5.00%   5.20%   5.30%
# 7    Kannada   3.30%   3.50%   3.70%   3.90%   3.60%   3.90%   4.00%   4.10%
# 8  Malayalam   3.50%   3.60%   3.80%   4.00%   2.70%   3.10%   3.30%   3.40%
# 9       Odia   2.70%   2.90%   3.10%   3.30%   2.70%   3.10%   3.20%   3.30%
#
#      1981    1991    2001    2011
# 0  43.70%  40.60%  41.00%  43.60%
# 1   9.30%   8.30%   8.10%   8.00%
# ...

# %%
import matplotlib.pyplot as plt


languages = ["Hindi", "Bengali", "Marathi", "Telugu", "Tamil", "Gujarati", "Urdu", "Kannada", "Malayalam", "Odia"]


years = [1900, 1911, 1921, 1931, 1941, 1951, 1961, 1971, 1981, 1991, 2001, 2011]


data = [
    [26.60, 28.90, 31.80, 32.10, 26.60, 44.30, 44.10, 43.10, 43.70, 40.60, 41.00, 43.60],
    [10.80, 10.70, 11.00, 11.60, 8.00, 9.10, 9.20, 9.40, 9.30, 8.30, 8.10, 8.00],
    [7.10, 7.60, 7.90, 7.80, 6.80, 7.00, 7.10, 7.30, 7.20, 6.90, 7.00, 6.80],
    [5.90, 6.20, 6.40, 6.60, 6.70, 7.20, 7.30, 7.50, 7.80, 7.40, 7.50, 6.70],
    [5.30, 5.50, 5.70, 5.90, 6.30, 6.80, 7.00, 7.30, 7.50, 7.30, 7.40, 6.30],
    [4.30, 4.60, 4.80, 4.90, 5.00, 5.30, 5.50, 5.70, 5.90, 5.70, 5.80, 5.00],
    [2.50, 2.90, 3.20, 3.40, 4.20, 5.00, 5.20, 5.30, 5.40, 5.20, 5.30, 4.20],
    [3.30, 3.50, 3.70, 3.90, 3.60, 3.90, 4.00, 4.10, 4.30, 4.10, 4.20, 3.60],
    [3.50, 3.60, 3.80, 4.00, 2.70, 3.10, 3.30, 3.40, 3.60, 3.70, 3.70, 2.70],
    [2.70, 2.90, 3.10, 3.30, 2.70, 3.10, 3.20, 3.30, 3.50, 3.50, 3.60, 2.70]
]


fig, ax = plt.subplots(figsize=(12, 6))


for i, language in enumerate(languages):
    ax.plot(years, data[i], marker='o', label=language)


ax.set_xlabel("Year")
ax.set_ylabel("Percentage of Speakers")
ax.set_title("Language Percentage in India (1900-2011)")


ax.legend(loc='upper left', bbox_to_anchor=(1, 1))


plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
file1=pd.read_csv("bihar - Sheet1.csv")
print(file1)
# Out:
#    Language    1901    1911    1921    1931    1941    1951    1961    1971
# 0     Hindi  35.40%  38.50%  41.50%  44.50%  47.50%  50.50%  53.50%  56.50%  \
# 1  Bhojpuri  30.40%  33.50%  36.50%  39.50%  42.50%  45.50%  48.50%  51.50%
# 2  Maithili  15.40%  18.50%  21.50%  24.50%  27.50%  30.50%  33.50%  36.50%
# 3    Magahi  10.40%  13.50%  16.50%  19.50%  22.50%  25.50%  28.50%  31.50%
# 4      Urdu   5.40%   8.50%  11.50%  14.50%  17.50%  20.50%  23.50%  26.50%
#
#      1981    1991    2001    2011
# 0  59.50%  62.50%  65.50%  80.40%
# 1  54.50%  57.50%  60.50%  24.86%
# 2  39.50%  42.50%  45.50%  12.55%
# 3  34.50%  37.50%  40.50%  10.87%
# 4  29.50%  32.50%  35.50%   8.42%

# %%
import matplotlib.pyplot as plt


years = list(range(1901, 2012, 10))
hindi_percentages = [35.40, 38.50, 41.50, 44.50, 47.50, 50.50, 53.50, 56.50, 59.50, 62.50, 65.50, 80.40]
bhojpuri_percentages = [30.40, 33.50, 36.50, 39.50, 42.50, 45.50, 48.50, 51.50, 54.50, 57.50, 60.50, 24.86]
maithili_percentages = [15.40, 18.50, 21.50, 24.50, 27.50, 30.50, 33.50, 36.50, 39.50, 42.50, 45.50, 12.55]
magahi_percentages = [10.40, 13.50, 16.50, 19.50, 22.50, 25.50, 28.50, 31.50, 34.50, 37.50, 40.50, 10.87]
urdu_percentages = [5.40, 8.50, 11.50, 14.50, 17.50, 20.50, 23.50, 26.50, 29.50, 32.50, 35.50, 8.42]


plt.figure(figsize=(12, 6))
plt.plot(years, hindi_percentages, label='Hindi', marker='o')
plt.plot(years, bhojpuri_percentages, label='Bhojpuri', marker='s')
plt.plot(years, maithili_percentages, label='Maithili', marker='^')
plt.plot(years, magahi_percentages, label='Magahi', marker='D')
plt.plot(years, urdu_percentages, label='Urdu', marker='x')


plt.xlabel('Year')
plt.ylabel('Percentage')
plt.title('Language Percentage Over Time (Line Graph)')
plt.legend()
plt.grid(True)


plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
file1=pd.read_csv("languages_spoken_in_delhi.csv")
print(file1)
# Out:
#   Language  1951  1961  1971  1981  1991  2001  2011
# 0    Hindi  60.4  61.8  62.3  62.8  63.3  63.8  64.3
# 1  Punjabi  24.5  25.5  26.3  27.1  27.9  28.7  29.5
# 2     Urdu   8.3   6.7   5.5   4.6   3.8   3.0   2.3
# 3  Bengali   1.8   1.9   2.0   2.1   2.2   2.3   2.4

# %%
import matplotlib.pyplot as plt


years = [1951, 1961, 1971, 1981, 1991, 2001, 2011]
hindi = [60.4, 61.8, 62.3, 62.8, 63.3, 63.8, 64.3]
punjabi = [24.5, 25.5, 26.3, 27.1, 27.9, 28.7, 29.5]
urdu = [8.3, 6.7, 5.5, 4.6, 3.8, 3.0, 2.3]
bengali = [1.8, 1.9, 2.0, 2.1, 2.2, 2.3, 2.4]


plt.figure(figsize=(10, 6))
plt.plot(years, hindi, marker='o', label='Hindi')
plt.plot(years, punjabi, marker='o', label='Punjabi')
plt.plot(years, urdu, marker='o', label='Urdu')
plt.plot(years, bengali, marker='o', label='Bengali')


plt.title('Language Percentage in Delhi Over the Years')
plt.xlabel('Year')
plt.ylabel('Percentage of Speakers')
plt.legend()


plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
file1=pd.read_csv("languages_spoken_in_top_20_indian_cities.csv")
print(file1)
# Out:
#              City  Language  1951  1961  1971  1981  1991  2001  2011
# 0          Mumbai     Hindi  60.4  61.8  62.3  62.8  63.3  63.8  64.3
# 1          Mumbai   Marathi  52.4  51.8  51.3  50.8  50.3  49.8  49.3
# 2           Delhi     Hindi  60.4  61.8  62.3  62.8  63.3  63.8  64.3
# 3         Kolkata   Bengali  78.8  79.3  79.8  80.3  80.8  81.3  81.8
# 4       Bengaluru   Kannada  65.4  66.8  67.3  67.8  68.3  68.8  69.3
# 5         Chennai     Tamil  79.8  80.3  80.8  81.3  81.8  82.3  82.8
# 6       Hyderabad    Telugu  65.4  66.8  67.3  67.8  68.3  68.8  69.3
# 7            Pune   Marathi  65.4  66.8  67.3  67.8  68.3  68.8  69.3
# 8       Ahmedabad  Gujarati  79.8  80.3  80.8  81.3  81.8  82.3  82.8
# 9          Jaipur     Hindi  65.4  66.8  67.3  67.8  68.3  68.8  69.3
# 10          Surat  Gujarati  79.8  80.3  80.8  81.3  81.8  82.3  82.8
# 11           Agra     Hindi  65.4  66.8  67.3  67.8  68.3  68.8  69.3
# ...

# %%
import matplotlib.pyplot as plt


cities = [
    'Mumbai', 'Delhi', 'Kolkata', 'Bengaluru', 'Chennai', 'Hyderabad', 'Pune',
    'Ahmedabad', 'Jaipur', 'Surat', 'Agra', 'Varanasi', 'Visakhapatnam',
    'Lucknow', 'Kanpur', 'Indore'
]

years = [1951, 1961, 1971, 1981, 1991, 2001, 2011]
hindi_percentages = [
    [60.4, 61.8, 62.3, 62.8, 63.3, 63.8, 64.3],  # Hindi in Mumbai
    [60.4, 61.8, 62.3, 62.8, 63.3, 63.8, 64.3],  # Hindi in Delhi
    [78.8, 79.3, 79.8, 80.3, 80.8, 81.3, 81.8],  # Bengali in Kolkata
    [65.4, 66.8, 67.3, 67.8, 68.3, 68.8, 69.3],  # Kannada in Bengaluru
    [79.8, 80.3, 80.8, 81.3, 81.8, 82.3, 82.8],  # Tamil in Chennai
    [65.4, 66.8, 67.3, 67.8, 68.3, 68.8, 69.3],  # Telugu in Hyderabad
    [65.4, 66.8, 67.3, 67.8, 68.3, 68.8, 69.3],  # Marathi in Pune
    [79.8, 80.3, 80.8, 81.3, 81.8, 82.3, 82.8],  # Gujarati in Ahmedabad
    [65.4, 66.8, 67.3, 67.8, 68.3, 68.8, 69.3],  # Hindi in Jaipur
    [79.8, 80.3, 80.8, 81.3, 81.8, 82.3, 82.8],  # Gujarati in Surat
    [65.4, 66.8, 67.3, 67.8, 68.3, 68.8, 69.3],  # Hindi in Agra
    [65.4, 66.8, 67.3, 67.8, 68.3, 68.8, 69.3],  # Hindi in Varanasi
    [65.4, 66.8, 67.3, 67.8, 68.3, 68.8, 69.3],  # Telugu in Visakhapatnam
    [65.4, 66.8, 67.3, 67.8, 68.3, 68.8, 69.3],  # Hindi in Lucknow
    [65.4, 66.8, 67.3, 67.8, 68.3, 68.8, 69.3],  # Hindi in Kanpur
    [65.4, 66.8, 67.3, 67.8, 68.3, 68.8, 69.3]   # Hindi in Indore
]


plt.figure(figsize=(12, 6))

for i, city in enumerate(cities):
    plt.plot(years, hindi_percentages[i], marker='o', label=city)


plt.title('Percentage of Hindi Speakers in Top 20 Indian Cities Over the Years')
plt.xlabel('Year')
plt.ylabel('Percentage of Hindi Speakers')
plt.legend(cities, loc='upper left', bbox_to_anchor=(1, 1))


plt.grid(True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Data
data = {
    'Year': [str(year) for year in range(1901, 2012, 10)],
    'Hindi': [35.40, 38.50, 41.50, 44.50, 47.50, 50.50, 53.50, 56.50, 59.50, 62.50, 65.50, 80.40],
    'Bhojpuri': [30.40, 33.50, 36.50, 39.50, 42.50, 45.50, 48.50, 51.50, 54.50, 57.50, 60.50, 24.86],
    'Maithili': [15.40, 18.50, 21.50, 24.50, 27.50, 30.50, 33.50, 36.50, 39.50, 42.50, 45.50, 12.55],
    'Magahi': [10.40, 13.50, 16.50, 19.50, 22.50, 25.50, 28.50, 31.50, 34.50, 37.50, 40.50, 10.87],
    'Urdu': [5.40, 8.50, 11.50, 14.50, 17.50, 20.50, 23.50, 26.50, 29.50, 32.50, 35.50, 8.42]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Set the 'Year' column as the index
df.set_index('Year', inplace=True)

# Create a heatmap using Seaborn
plt.figure(figsize=(12, 6))
sns.heatmap(df, annot=True, cmap='YlGnBu', linewidths=0.5, fmt=".2f")
plt.title('Language Percentage Over Time (Heatmap)')
plt.xlabel('Language')
plt.ylabel('Year')

# Display the heatmap
plt.show()
